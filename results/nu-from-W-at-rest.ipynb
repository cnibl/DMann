# %% [markdown]
# # Neutrinos from $W$ bosons at rest
# This notebook plots some results from simulations of $m_\chi=80.4$ GeV, i.e. producing the $W$ bosons at rest.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Theta distribution

# %%
cThPyt = np.genfromtxt("da-pyt8-mx80-ch24-int14-costh.dat", skip_header=7)
fig, ax = plt.subplots()
ax.plot(cThPyt[:,0],cThPyt[:,1],label=r"$\cos\theta$, Pythia")
ax.set_ylim(0,0.04)
ax.legend(loc="best")

# %% [markdown]
# ## Energy distribution

# %%
EPyt = np.genfromtxt("da-pyt8-mx80-ch24-int14.dat", skip_header=7)
fig, ax = plt.subplots()
ax.plot(EPyt[:,0],EPyt[:,1],label=r"$E_{\rm kin}$, Pythia")
ax.legend(loc="best")

# %% [markdown]
# ## Trying with spin 1 mediator
# Setting `spinType=3` ($2s+1$, so $s=1$) when setting up general resonance properties in Pythia.

# %%
cThPyt = np.genfromtxt("da-pyt8-mx80-ch24-int14-costh-spin1.dat", skip_header=7)
fig, ax = plt.subplots()
ax.plot(cThPyt[:,0],cThPyt[:,1],label=r"$\cos\theta$, Pythia, $s=1$")
ax.set_ylim(0,0.04)
ax.legend(loc="best")

# %%
EPyt = np.genfromtxt("da-pyt8-mx80-ch24-int14-spin1.dat", skip_header=7)
fig, ax = plt.subplots()
ax.plot(EPyt[:,0],EPyt[:,1],label=r"$E_{\rm kin}$, Pythia, $s=1$")
ax.legend(loc="best")
